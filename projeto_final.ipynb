# %% [markdown]
# # **📊 Projeto Final: Análise de Dados Educacionais**
#
# ## **Bem-vindo ao Projeto Final do Curso de Python da FEA.dev!** 🎉
#
# Chegou a hora de colocar em prática tudo o que você aprendeu no curso! Neste desafio, você vai explorar e analisar um conjunto de dados sobre o desempenho acadêmico de estudantes. Seu objetivo será realizar uma análise exploratória completa e responder a uma pergunta norteadora, gerando insights a partir dos dados.
#
# ---
#
# ## **🚀 O Desafio**
#
# ### **Pergunta Norteadora**:
# **"Quais fatores demográficos, acadêmicos e comportamentais mais influenciam a classificação e a média de notas dos estudantes?"**
#
# As variáveis de interesse são **`Classificacao_Notas` e `Media_Notas`**. Investigue como elas se relaciona com outros fatores, como idade, gênero, faltas, horas de estudo e participação em atividades extracurriculares. 📝
#
# ---
#
# ## **📌 Etapas do Desafio**
#
# 1. **Importação e Exploração dos Dados**:
#    - Leia o dataset e obtenha uma visão geral das informações.
#    - Verifique o formato dos dados, tipos de variáveis e valores ausentes ou duplicados.
#
# 2. **Preparação e Limpeza**:
#    - Renomeie colunas, trate valores ausentes e ajuste os dados conforme necessário.
#    - Crie novas colunas, se útil para a análise ou visualização.
#
# 3. **Análise Exploratória**:
#    - Investigue a relação entre **`Classificacao_Notas` e `Media_Notas`** com outras variáveis.
#    - Exemplos de perguntas a explorar:
#      - Alunos que participam de atividades extracurriculares têm melhor desempenho?
#      - O número de faltas impacta a classificação?
#      - Há diferenças de desempenho por idade, gênero ou etnia?
#
# 4. **Visualização de Dados**:
#    - Crie gráficos (ex.: histogramas, boxplots, scatter plots) para apresentar os padrões encontrados de forma clara e visualmente atraente. 📈
#
# 5. **Conclusões**:
#    - Resuma os principais insights.
#    - Destaque os fatores mais relevantes que influenciam as classificações e as médias de notas.
#
# ---
#
# ## **📋 Regras e Diretrizes**
# - Este desafio é focado em análise exploratória e visualização de dados.
# - Documente seu processo com comentários no código.
# - Seja criativo nas análises e visualizações! 🖌️
#
# ---
#
# ## **Dica Extra:**
#
# Use documentações, tutoriais e até pesquisas na internet para te ajudar, mas lembre-se: é essencial entender e refletir sobre o que está aplicando. 🚫 Evite usar o GPT sem raciocinar!
#
# ---
#
# ## **🎯 Objetivos de Aprendizado**
# - Reforçar os conceitos aprendidos ao longo do curso.
# - Manipular dados com **`pandas`** e **`numpy`**.
# - Criar visualizações com **`matplotlib`** e **`seaborn`**.
# - Desenvolver uma abordagem crítica para interpretar padrões em dados.
#
# ---
#
# ## **📝 Como entregar o Projeto Final**
#
# ### Passo a Passo:
# 1. **Prepare seu notebook**:
#    - Certifique-se de que ele está completo, organizado e com comentários explicando seu processo.
# 2. **Envie apenas esse arquivo ipynb!**:
#    - Acesse o formulário oficial: **[Link do Formulário](https://forms.gle/oDvYmwKfxscKbMaF8)**.
#    - Anexe o arquivo do seu notebook na aba "Projeto Final" e **NÃO arquive o dataset, `dados_estudantes.csv`, utilizado!**
#    - Este é o mesmo formulário utilizado para as listas de exercícios. Envie tudo junto para garantir o registro correto.
#
# ### **Prazos e Certificação**:
# - **Prazo de entrega**: Aumentamos para dia **15/12** (23h59).
# - **Certificação**: Se você completar pelo menos **70% das listas e o projeto final**, receberá um certificado oficial de conclusão. 🎓
#
# ---
#
# ## **🎁 Benefícios Extras para Alunos USP**
# Se você é aluno(a) da USP, terá a oportunidade de participar do nosso **Processo Seletivo** para integrar a equipe da FEA.dev! Após a entrega do projeto final, fique de olho no seu e-mail para mais informações.
#
# ---
#
# ## **📚 Origem dos Dados**
# Este dataset foi disponibilizado por Rabie El Kharoua no Kaggle e está licenciado sob CC BY 4.0:
#
# > El Kharoua, R. (2024). Students Performance Dataset.
# > Disponível em: [Kaggle Dataset Link](https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset).
#
# ---
#
# ## **💡 PS: Você Chegou Até Aqui!**
#
# Estamos **muito orgulhosos** de ver o quanto você evoluiu ao longo do curso! 💪
# Este projeto é a chance perfeita de consolidar tudo o que aprendeu e mostrar do que é capaz.
#
# Lembre-se: a jornada no mundo da programação é cheia de descobertas, desafios e até frustrações (Sabemos bem como é kkk), mas cada linha de código escrita é um passo a mais rumo ao seu sucesso. Não pare por aqui! Continue explorando, aprendendo e se desafiando. O **infinito** é o seu limite.
#
# Parabéns por ter chegado até aqui! 🎉 Estamos torcendo por você e muito animados para ver o seu projeto final. Vamos juntos nessa jornada incrível! 🧑‍💻
#
# 🎯 **Agora é com você! Explore, analise e descubra os padrões escondidos nos dados. Boa sorte!** 🍀

# %% [markdown]
# ---
#
# ## **📊 Descrição das Colunas do DataFrame**
#
# ### **Identificação do Estudante**
# - **ID_Aluno**: Identificador único para cada aluno (de 1001 a 3392).
#
# ### **👥 Detalhes Demográficos**
# - **Idade**: Idade dos estudantes, variando de 15 a 18 anos.
# - **Genero**: Gênero do estudante:
#   - 0: Masculino
#   - 1: Feminino
# - **Etnia**: Etnia dos estudantes:
#   - 0: Caucasiano
#   - 1: Afrodescendente
#   - 2: Asiático
#   - 3: Outra
#
# ### **👨‍👩‍👧 Educação dos Pais**
# - **Escolaridade_Pais**: Nível de escolaridade dos pais:
#   - 0: Nenhum
#   - 1: Ensino Médio
#   - 2: Alguma Faculdade
#   - 3: Graduação
#   - 4: Pós-Graduação ou Superior
#
# ### **📚 Hábitos de Estudo**
# - **Horas_Estudo_Semanais**: Tempo de estudo semanal em horas (0 a 20).
# - **Faltas**: Número de faltas no ano letivo (0 a 30).
# - **Aulas_Particulares**: Participação em aulas particulares:
#   - 0: Não
#   - 1: Sim
#
# ### **👨‍👩‍👧 Envolvimento Parental**
# - **Apoio_Pais**: Nível de apoio dos pais:
#   - 0: Nenhum
#   - 1: Baixo
#   - 2: Moderado
#   - 3: Alto
#   - 4: Muito Alto
#
# ### **🏫 Atividades Extracurriculares**
# - **Atividades_Extracurriculares**: Participação em atividades extracurriculares:
#   - 0: Não
#   - 1: Sim
# - **Esportes**: Participação em esportes:
#   - 0: Não
#   - 1: Sim
# - **Musica**: Participação em atividades musicais:
#   - 0: Não
#   - 1: Sim
# - **Voluntariado**: Participação em atividades de voluntariado:
#   - 0: Não
#   - 1: Sim
#
# ### **📈 Desempenho Acadêmico**
# - **Media_Notas**: Média das notas (GPA), variando de 2.0 a 4.0.
# - **Classificacao_Notas**: Classificação do aluno com base na média das notas:
#   - 0: 'A' (Média >= 3.5)
#   - 1: 'B' (3.0 <= Média < 3.5)
#   - 2: 'C' (2.5 <= Média < 3.0)
#   - 3: 'D' (2.0 <= Média < 2.5)
#   - 4: 'F' (Média < 2.0)
#
# ---

# %%
# Importando as bibliotecas estudadas durante o curso
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Importando o dataset

# Verificando as primeiras linhas do dataset

df_dados_estudantes = pd.read_csv("dados_estudantes.csv", sep= ',')

df_dados_estudantes
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
traducao_colunas = {
    "StudentID": "ID_Aluno",
    "Age": "Idade",
    "Gender": "Genero",
    "Ethnicity": "Etnia",
    "ParentalEducation": "Escolaridade_Pais",
    "StudyTimeWeekly": "Horas_Estudo_Semanais",
    "Absences": "Faltas",
    "Tutoring": "Aulas_Particulares",
    "ParentalSupport": "Apoio_Pais",
    "Extracurricular": "Atividades_Extracurriculares",
    "Sports": "Esportes",
    "Music": "Musica",
    "Volunteering": "Voluntariado",
    "GPA": "Media_Notas",
    "GradeClass": "Classificacao_Notas"
}

# Renomear as colunas
df_dados_estudantes = df_dados_estudantes.rename(columns=traducao_colunas)

df_dados_estudantes.head(10)
# Out:
#    ID_Aluno  Idade  Genero  Etnia  Escolaridade_Pais  Horas_Estudo_Semanais  \
# 0      1001     17       1      0                  2              19.833723
# 1      1002     18       0      0                  1              15.408756
# 2      1003     15       0      2                  3               4.210570
# 3      1004     17       1      0                  3              10.028829
# 4      1005     17       1      0                  2               4.672495
# 5      1006     18       0      0                  1               8.191219
# 6      1007     15       0      1                  1              15.601680
# 7      1008     15       1      1                  4              15.424496
# 8      1009     17       0      0                  0               4.562008
# 9      1010     16       1      0                  1              18.444466
#
#    Faltas  Aulas_Particulares  Apoio_Pais  Atividades_Extracurriculares  \
# ...

# %%
# Agora está por conta própria e pronto para brilhar! 🌟

### 🔍 **Pergunta Norteadora** ###
# Quais fatores demográficos, acadêmicos e comportamentais mais influenciam a classificação e a média de notas dos estudantes?

# 🛠️ **Dicas para começar:**
# - Dê uma boa olhada no dataset.
# - Explore as relações entre a variável `Classificacao_Notas` e outros fatores, como gênero, horas de estudo, faltas, etc.
# - Use gráficos e tabelas para visualizar os padrões encontrados.
# - Escreva suas reflexões e hipóteses sobre o que você encontrou.
# - E o mais importante: divirta-se no processo de análise! 😄

# Não há limite para o número de células ou análises. O espaço é todo seu! 🚀

# **SEU CÓDIGO COMEÇA AQUI** 👇

# %% [markdown]
# Primeiro passo, conferir as informações do dataframe.

# %%
#Usando shape para conferir as dimensões do dataframe
df_dados_estudantes.shape
# Out:
# (2392, 15)

# %%
#Conferindo os tipos de dados utilizados no dataframe com dtypes
df_dados_estudantes.dtypes
# Out:
# ID_Aluno                          int64
# Idade                             int64
# Genero                            int64
# Etnia                             int64
# Escolaridade_Pais                 int64
# Horas_Estudo_Semanais           float64
# Faltas                            int64
# Aulas_Particulares                int64
# Apoio_Pais                        int64
# Atividades_Extracurriculares      int64
# Esportes                          int64
# Musica                            int64
# Voluntariado                      int64
# Media_Notas                     float64
# Classificacao_Notas             float64
# dtype: object

# %% [markdown]
# Para seguir os padrões apresentados na 📊 Descrição das Colunas do DataFrame, irei alterar o tipo de dados de algumas colunas.

# %%
#Alterando a coluna Media_Notas para float com 1 casa decimal
df_dados_estudantes[['Media_Notas']] = df_dados_estudantes[['Media_Notas']].astype(float).round(1)

# %%
#Alterando as colunas Horas_Estudo_Semanais e Classificacao_Notas para Int
df_dados_estudantes[['Horas_Estudo_Semanais', 'Classificacao_Notas']] = df_dados_estudantes[['Horas_Estudo_Semanais', 'Classificacao_Notas']].astype(int)

#Visualizando a alteração das 3 colunas
df_dados_estudantes.dtypes
# Out:
# ID_Aluno                          int64
# Idade                             int64
# Genero                            int64
# Etnia                             int64
# Escolaridade_Pais                 int64
# Horas_Estudo_Semanais             int64
# Faltas                            int64
# Aulas_Particulares                int64
# Apoio_Pais                        int64
# Atividades_Extracurriculares      int64
# Esportes                          int64
# Musica                            int64
# Voluntariado                      int64
# Media_Notas                     float64
# Classificacao_Notas               int64
# dtype: object

# %%
#Visualizando o dataframe após as alterações
df_dados_estudantes
# Out:
#       ID_Aluno  Idade  Genero  Etnia  Escolaridade_Pais  \
# 0         1001     17       1      0                  2
# 1         1002     18       0      0                  1
# 2         1003     15       0      2                  3
# 3         1004     17       1      0                  3
# 4         1005     17       1      0                  2
# ...        ...    ...     ...    ...                ...
# 2387      3388     18       1      0                  3
# 2388      3389     17       0      0                  1
# 2389      3390     16       1      0                  2
# 2390      3391     16       1      1                  0
# 2391      3392     16       1      0                  2
#
#       Horas_Estudo_Semanais  Faltas  Aulas_Particulares  Apoio_Pais  \
# 0                        19       7                   1           2
# 1                        15       0                   0           1
# 2                         4      26                   0           2
# ...

# %%
#Utilizar o info para visulizar o dataframe com mais detalhes
df_dados_estudantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID_Aluno                      2392 non-null   int64
#  1   Idade                         2392 non-null   int64
#  2   Genero                        2392 non-null   int64
#  3   Etnia                         2392 non-null   int64
#  4   Escolaridade_Pais             2392 non-null   int64
#  5   Horas_Estudo_Semanais         2392 non-null   int64
#  6   Faltas                        2392 non-null   int64
#  7   Aulas_Particulares            2392 non-null   int64
#  8   Apoio_Pais                    2392 non-null   int64
#  9   Atividades_Extracurriculares  2392 non-null   int64
#  10  Esportes                      2392 non-null   int64
#  11  Musica                        2392 non-null   int64
#  12  Voluntariado                  2392 non-null   int64
# ...

# %%
#Conferir se existe valores ausentes no dataframe
df_dados_estudantes.isna().sum()
# Out:
# ID_Aluno                        0
# Idade                           0
# Genero                          0
# Etnia                           0
# Escolaridade_Pais               0
# Horas_Estudo_Semanais           0
# Faltas                          0
# Aulas_Particulares              0
# Apoio_Pais                      0
# Atividades_Extracurriculares    0
# Esportes                        0
# Musica                          0
# Voluntariado                    0
# Media_Notas                     0
# Classificacao_Notas             0
# dtype: int64

# %%
#Conferir se existe valores nulos no dataframe
df_dados_estudantes.isnull().sum()
# Out:
# ID_Aluno                        0
# Idade                           0
# Genero                          0
# Etnia                           0
# Escolaridade_Pais               0
# Horas_Estudo_Semanais           0
# Faltas                          0
# Aulas_Particulares              0
# Apoio_Pais                      0
# Atividades_Extracurriculares    0
# Esportes                        0
# Musica                          0
# Voluntariado                    0
# Media_Notas                     0
# Classificacao_Notas             0
# dtype: int64

# %%
#Por fim fazer uma análise descritiva do dataframe
df_dados_estudantes.describe()
# Out:
#           ID_Aluno        Idade       Genero        Etnia  Escolaridade_Pais  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        Horas_Estudo_Semanais       Faltas  Aulas_Particulares   Apoio_Pais  \
# count            2392.000000  2392.000000         2392.000000  2392.000000
# mean                9.275502    14.541388            0.301421     2.122074
# ...

# %% [markdown]
# Após visiualizar as principais características do dataframe, agora é hora modelar e tratar os dados para dar início à análise do projeto.
#
# Próximo passo é alterar os valores das colunas, pelos valores das legendas informadas nas 📊Descrições das Colunas do DataFrame para assim, termos uma melhor visualização e entendimento dos dados, uma vez que todos os valores dos dados foram inseridos de forma numérica.

# %%
#O ID_Aluno está contando de 1001 à 3392, para alterar a contagem para 1 à 2392 usarei o método apply lambda para 
# fazer essa alteração.

#Alterando os valores do ID_Aluno para contar do número 1 em diante
df_dados_estudantes['ID_Aluno'] = df_dados_estudantes['ID_Aluno'].apply(lambda x: x - 1000)

# %%
#Para alterar os valores numéricos pelos seus respectivos valores informados na descrição, usarei o método replace 
# para reverter os números cadastrados em seus devidos valores informados.

#Alterando os valores da descrição da coluna Gênero
df_dados_estudantes['Genero'] = df_dados_estudantes['Genero'].replace({
     0: 'Masculino', 
     1: 'Feminino'
})

# %%
#Alterando os valores da descrição da coluna Etnia
df_dados_estudantes['Etnia'] = df_dados_estudantes['Etnia'].replace({
    0: 'Caucasiano', 
    1: 'Afrodescendente', 
    2: 'Asiático', 
    3: 'Outra'
})

# %%
#Alterando os valores da descrição da coluna Escolaridade dos Pais
df_dados_estudantes['Escolaridade_Pais'] = df_dados_estudantes['Escolaridade_Pais'].replace({
     0: 'Nenhum', 
     1: 'Ensino Médio', 
     2: 'Alguma Faculdade', 
     3: 'Graduação', 
     4: 'Pós-Graduação ou Superior'
})

# %%
#Alterando os valores da descrição da coluna Aulas Particulares
df_dados_estudantes['Aulas_Particulares'] = df_dados_estudantes['Aulas_Particulares'].replace({
    0: 'Não', 
    1: 'Sim'
})

# %%
#Alterando os valores da descrição da coluna Apoio dos Pais
df_dados_estudantes['Apoio_Pais'] = df_dados_estudantes['Apoio_Pais'].replace({
    0: 'Nenhum', 
    1: 'Baixo', 
    2: 'Moderado', 
    3: 'Alto', 
    4: 'Muito Alto'
})

# %%
#Alterando os valores da descrição da coluna Atividades Extracurriculares
df_dados_estudantes['Atividades_Extracurriculares'] = df_dados_estudantes['Atividades_Extracurriculares'].replace({
    0: 'Não',
    1: 'Sim'
})

# %%
#Alterando os valores da descrição da coluna Esportes
df_dados_estudantes['Esportes'] = df_dados_estudantes['Esportes'].replace({
     0: 'Não', 
     1: 'Sim'
})

# %%
#Alterando os valores da descrição da coluna Musica
df_dados_estudantes['Musica'] = df_dados_estudantes['Musica'].replace({
    0: 'Não', 
    1: 'Sim'
})

# %%
#Alterando os valores da descrição da coluna Voluntariado
df_dados_estudantes['Voluntariado'] = df_dados_estudantes['Voluntariado'].replace({
    0: 'Não', 
    1: 'Sim'
})

# %%
#Alterando os valores da descrição da coluna Classificacao_Notas
df_dados_estudantes['Classificacao_Notas'] = df_dados_estudantes['Classificacao_Notas'].replace({
    0: 'A', 
    1: 'B', 
    2: 'C', 
    3: 'D', 
    4: 'F'
})

# %%
#Agora que alterei todos os valores necessários para suas devidas descrições, é hora de visualizar o resultado em 
# um novo dataframe.

#Visualização do novo dataframe após a alteração das descrições das colunas
novo_df_estudantes = df_dados_estudantes

novo_df_estudantes
# Out:
#       ID_Aluno  Idade     Genero            Etnia Escolaridade_Pais  \
# 0            1     17   Feminino       Caucasiano  Alguma Faculdade
# 1            2     18  Masculino       Caucasiano      Ensino Médio
# 2            3     15  Masculino         Asiático         Graduação
# 3            4     17   Feminino       Caucasiano         Graduação
# 4            5     17   Feminino       Caucasiano  Alguma Faculdade
# ...        ...    ...        ...              ...               ...
# 2387      2388     18   Feminino       Caucasiano         Graduação
# 2388      2389     17  Masculino       Caucasiano      Ensino Médio
# 2389      2390     16   Feminino       Caucasiano  Alguma Faculdade
# 2390      2391     16   Feminino  Afrodescendente            Nenhum
# 2391      2392     16   Feminino       Caucasiano  Alguma Faculdade
#
#       Horas_Estudo_Semanais  Faltas Aulas_Particulares  Apoio_Pais  \
# 0                        19       7                Sim    Moderado
# ...

# %% [markdown]
# Ao analisar o novo dataframe, observei que existem inconsistências nos valores em relação a coluna Media_Notas e Classificacao_Notas. Para corrigir esse problema e não haver divergências entre as análises, irei corrigir os valores usando o método apply com lambda de acordo com as informações descritas na 📈 Descrição do Desempenho Acadêmico.

# %%
#Aplicando o lambda para corrigir os valores da Classificacao_Notas em relação a Média_Notas
novo_df_estudantes['Classificacao_Notas_Lambda'] = novo_df_estudantes['Media_Notas'].apply(lambda x: 'A' if x >= 3.5 else 'B' if x >= 3.0 else 'C' if x >= 2.5 else 'D' if x >= 2.0 else 'F')

novo_df_estudantes
# Out:
#       ID_Aluno  Idade     Genero            Etnia Escolaridade_Pais  \
# 0            1     17   Feminino       Caucasiano  Alguma Faculdade
# 1            2     18  Masculino       Caucasiano      Ensino Médio
# 2            3     15  Masculino         Asiático         Graduação
# 3            4     17   Feminino       Caucasiano         Graduação
# 4            5     17   Feminino       Caucasiano  Alguma Faculdade
# ...        ...    ...        ...              ...               ...
# 2387      2388     18   Feminino       Caucasiano         Graduação
# 2388      2389     17  Masculino       Caucasiano      Ensino Médio
# 2389      2390     16   Feminino       Caucasiano  Alguma Faculdade
# 2390      2391     16   Feminino  Afrodescendente            Nenhum
# 2391      2392     16   Feminino       Caucasiano  Alguma Faculdade
#
#       Horas_Estudo_Semanais  Faltas Aulas_Particulares  Apoio_Pais  \
# 0                        19       7                Sim    Moderado
# ...

# %% [markdown]
# Como eu havia notado, os valores estavam divergentes. Isso pode ser observado no dataframe comparando-se os valores entre Classificacao_Notas e Classificacao_Notas_Lambda que eu criei.

# %%
#Exluindo a coluna Classificacao_Notas (com os valores errados)
novo_df_estudantes = novo_df_estudantes.drop(columns=['Classificacao_Notas'])

novo_df_estudantes
# Out:
#       ID_Aluno  Idade     Genero            Etnia Escolaridade_Pais  \
# 0            1     17   Feminino       Caucasiano  Alguma Faculdade
# 1            2     18  Masculino       Caucasiano      Ensino Médio
# 2            3     15  Masculino         Asiático         Graduação
# 3            4     17   Feminino       Caucasiano         Graduação
# 4            5     17   Feminino       Caucasiano  Alguma Faculdade
# ...        ...    ...        ...              ...               ...
# 2387      2388     18   Feminino       Caucasiano         Graduação
# 2388      2389     17  Masculino       Caucasiano      Ensino Médio
# 2389      2390     16   Feminino       Caucasiano  Alguma Faculdade
# 2390      2391     16   Feminino  Afrodescendente            Nenhum
# 2391      2392     16   Feminino       Caucasiano  Alguma Faculdade
#
#       Horas_Estudo_Semanais  Faltas Aulas_Particulares  Apoio_Pais  \
# 0                        19       7                Sim    Moderado
# ...

# %%
#Renomeando a coluna Classificacao_Notas_Lambda para o nome original Classificacao_Notas
novo_df_estudantes = novo_df_estudantes.rename(columns={'Classificacao_Notas_Lambda': 'Classificacao_Notas'})

novo_df_estudantes
# Out:
#       ID_Aluno  Idade     Genero            Etnia Escolaridade_Pais  \
# 0            1     17   Feminino       Caucasiano  Alguma Faculdade
# 1            2     18  Masculino       Caucasiano      Ensino Médio
# 2            3     15  Masculino         Asiático         Graduação
# 3            4     17   Feminino       Caucasiano         Graduação
# 4            5     17   Feminino       Caucasiano  Alguma Faculdade
# ...        ...    ...        ...              ...               ...
# 2387      2388     18   Feminino       Caucasiano         Graduação
# 2388      2389     17  Masculino       Caucasiano      Ensino Médio
# 2389      2390     16   Feminino       Caucasiano  Alguma Faculdade
# 2390      2391     16   Feminino  Afrodescendente            Nenhum
# 2391      2392     16   Feminino       Caucasiano  Alguma Faculdade
#
#       Horas_Estudo_Semanais  Faltas Aulas_Particulares  Apoio_Pais  \
# 0                        19       7                Sim    Moderado
# ...

# %% [markdown]
# Agora que todas as colunas e seus valores foram remodelados e corrigidos, temos uma visão melhorada e precisa das informações.
#
# É hora de extrair o máximo de insights.

# %% [markdown]
# 📝 **Análise dos Dados**

# %% [markdown]
# Agora irei aplicar o método Pivot_table para criar as relações entre as variáveis Classificacao_Notas e Media_Notas com todos os fatores descritos. Para termos resultados mais redundantes, irei aplicar como padrão a média nas visualizações, para isso vou aplicar o método mean().

# %%
#Como referência, utilizei os método Groupby e Mean para criar a relação das Médias das Notas entre a Classificação das Notas
#para realizar as comparações baseadas na Classificação.

#Aplicando o método Groupby para visualizar as médias da coluna Media_Notas pela Classificacao_Notas
media_geral_notas_classificacao = novo_df_estudantes.groupby('Classificacao_Notas')['Media_Notas'].mean().round(1)

media_geral_notas_classificacao
# Out:
# Classificacao_Notas
# A    3.6
# B    3.2
# C    2.7
# D    2.2
# F    1.2
# Name: Media_Notas, dtype: float64

# %% [markdown]
# 1 - 👥 Detalhes Demográficos

# %%
#Aplicando pivot_table para visualizar a relação das Médias das Notas entre a Idade 
media_idade = novo_df_estudantes.pivot_table(values='Media_Notas', index='Idade', columns='Classificacao_Notas', 
                                                 aggfunc='mean', fill_value=0)

media_idade.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Idade
# 15                   3.6  3.2  2.7  2.2  1.1
# 16                   3.6  3.2  2.7  2.2  1.2
# 17                   3.7  3.2  2.7  2.2  1.1
# 18                   3.6  3.2  2.7  2.2  1.2

# %%
#Aplicando pivot_table para visualizar a relação das Médias das Notas entre o Gênero 
media_genero = novo_df_estudantes.pivot_table(values='Media_Notas', index='Genero', columns='Classificacao_Notas', 
                                                 aggfunc='mean', fill_value=0)

media_genero.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Genero
# Feminino             3.7  3.2  2.7  2.2  1.2
# Masculino            3.6  3.2  2.7  2.2  1.2

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e a Etnia
media_etnia = novo_df_estudantes.pivot_table(values='Media_Notas', index='Etnia', columns='Classificacao_Notas', 
                                                 aggfunc='mean', fill_value=0,)
media_etnia.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Etnia
# Afrodescendente      3.6  3.2  2.7  2.2  1.2
# Asiático             3.6  3.2  2.7  2.2  1.2
# Caucasiano           3.7  3.2  2.7  2.2  1.1
# Outra                3.6  3.2  2.7  2.2  1.2

# %% [markdown]
# Anáslise exploratória sobre os Detalhes Demográficos:
#
# Na análise dos detalhes demográficos, o fator que mais influencia as notas é a IDADE, onde foi encotrada as notas mais baixas na classificação F. Em todas as categorias as classificações ficaram dentro da média na classificação de A a D.
#
# A conclusão da análise é de que os Detalhes Demográficos tem um impacto significativo nas notas dos estudantes em geral, especialmente a idade e a etnia.

# %% [markdown]
# 2 - 👨‍👩‍👧 Educação dos Pais

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e a Escolaridade dos Pais
media_escolaridade_pais = novo_df_estudantes.pivot_table(values='Media_Notas', index='Escolaridade_Pais', 
                                           columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_escolaridade_pais.round(1)
# Out:
# Classificacao_Notas          A    B    C    D    F
# Escolaridade_Pais
# Alguma Faculdade           3.7  3.2  2.7  2.2  1.2
# Ensino Médio               3.6  3.2  2.7  2.2  1.2
# Graduação                  3.6  3.2  2.7  2.2  1.1
# Nenhum                     3.6  3.1  2.7  2.2  1.2
# Pós-Graduação ou Superior  3.7  3.2  2.6  2.2  1.3

# %% [markdown]
# Análise exploratória sobre a Educação dos Pais:
#
# Nesta análise observa-se uma leve variação nas notas da classificação, variando de acordo com o grau de escolaridade dos pais, mostrando que nos graus mais elevados da categoria as notas são levemente mais altas.
#
# A conclusão da análise é de que a Educação dos Pais não impacta de forma significativa nas notas dos estudantes em geral, sofrendo impacto somente dentro das categorias da escolaridade dos pais.

# %% [markdown]
# 3 - 📚 Hábitos de Estudo

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e as Horas de Estudo Semanais
media_horas_estudos = novo_df_estudantes.pivot_table(values='Media_Notas', index='Horas_Estudo_Semanais', 
                                           columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_horas_estudos.round(1)
# Out:
# Classificacao_Notas      A    B    C    D    F
# Horas_Estudo_Semanais
# 0                      0.0  3.1  2.7  2.2  1.0
# 1                      3.8  3.1  2.7  2.2  1.1
# 2                      3.6  3.1  2.6  2.2  1.1
# 3                      0.0  3.2  2.7  2.2  1.1
# 4                      3.5  3.3  2.7  2.2  1.2
# 5                      3.6  3.2  2.7  2.2  1.0
# 6                      3.5  3.1  2.7  2.2  1.2
# 7                      3.8  3.1  2.7  2.2  1.1
# 8                      3.8  3.2  2.7  2.2  1.1
# 9                      3.7  3.2  2.7  2.2  1.2
# 10                     3.6  3.1  2.7  2.2  1.2
# 11                     3.5  3.1  2.7  2.2  1.2
# 12                     3.6  3.3  2.7  2.2  1.3
# 13                     3.6  3.2  2.7  2.2  1.2
# 14                     3.6  3.2  2.7  2.3  1.2
# 15                     3.7  3.1  2.6  2.2  1.2
# 16                     3.5  3.2  2.7  2.2  1.3
# 17                     3.6  3.2  2.7  2.2  1.2
# ...

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e as Faltas
media_faltas = novo_df_estudantes.pivot_table(values='Media_Notas', index='Faltas', 
                                           columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_faltas.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Faltas
# 0                    3.7  3.2  2.8  0.0  0.0
# 1                    3.6  3.2  2.8  2.4  0.0
# 2                    3.6  3.2  2.7  2.4  0.0
# 3                    3.6  3.2  2.8  2.4  0.0
# 4                    3.6  3.2  2.7  2.3  0.0
# 5                    0.0  3.2  2.7  2.3  1.9
# 6                    3.5  3.1  2.7  2.2  1.8
# 7                    0.0  3.1  2.7  2.2  1.8
# 8                    0.0  3.1  2.7  2.3  1.8
# 9                    3.5  3.1  2.6  2.2  1.7
# 10                   0.0  3.1  2.7  2.2  1.9
# 11                   0.0  0.0  2.6  2.2  1.8
# 12                   0.0  3.0  2.6  2.2  1.6
# 13                   0.0  3.0  2.6  2.2  1.7
# 14                   0.0  3.0  2.7  2.2  1.7
# 15                   0.0  0.0  2.5  2.2  1.6
# 16                   0.0  0.0  2.6  2.2  1.6
# 17                   0.0  0.0  2.5  2.2  1.5
# 18                   0.0  0.0  0.0  2.2  1.5
# 19                   0.0  0.0  0.0  2.1  1.4
# ...

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e as Aulas Particulares 
media_aulas_particulares =  novo_df_estudantes.pivot_table(values='Media_Notas', index='Aulas_Particulares', 
                                                               columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_aulas_particulares.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Aulas_Particulares
# Não                  3.6  3.2  2.7  2.2  1.1
# Sim                  3.7  3.2  2.7  2.2  1.3

# %% [markdown]
# Análise exploratória sobre os Hábitos de Estudo:
#
# Nesta análise é possível observar que nas horas de estudos semanais as notas sofrem leves variações, com as notas maiores nas escalas com mais horas. Nas faltas observa-se uma grande variação, com as notas maiores na escala 0 a 6 faltas e sofrendo uma queda constante chegando a 0.0 até 29 faltas. Nas aulas particulares a maior nota está em A para SIM e a menor em F para NÃO.
#
# A conclusão da análise é de que as faltas impactam tanto nas notas dos estudantes em geral, como dentro da própria categoria. As horas de estudo semanais tem um impacto significativo nas notas dos estudantes em geral devido a grande variação dentro da categoria. As aulas particulares não impactam de modo geral nas notas dos estudantes se mantendo equilibradas dentro da categoria.
#
# Resumindo, os hábitos de estudo influenciam de modo variável na classificação geral das notas e no desempenho dos alunos.

# %% [markdown]
# 4 - 👨‍👩‍👧 Envolvimento Parental

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e o Apoio dos Pais 
media_apoio_pais = novo_df_estudantes.pivot_table(values='Media_Notas', index='Apoio_Pais', 
                                                      columns='Classificacao_Notas', aggfunc='mean', fill_value=0)
media_apoio_pais.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Apoio_Pais
# Alto                 3.6  3.2  2.7  2.2  1.3
# Baixo                3.6  3.1  2.7  2.2  1.1
# Moderado             3.6  3.2  2.7  2.2  1.2
# Muito Alto           3.7  3.2  2.7  2.2  1.3
# Nenhum               3.6  3.2  2.7  2.2  0.9

# %% [markdown]
# Análise exploratória do Envolvimento Parental:
#
# Nesta análise, é possível observar que as notas são equilibradas na classificação das notas de A a D, com a nota mais alta na categoria MUITO ALTO. Na classificação da nota F é onde se encontra uma certa variação com a nota mais baixa na categoria NENHUM.
#
# A conclusão da análise é de que o envolvimento parental não tem um impacto significativo nas notas dos estudantes em geral, com atenção apenas para a nota F que demonstra uma variação nas notas do menor para o maior grau dentro da categoria.

# %% [markdown]
# 5 - 🏫 Atividades Extracurriculares

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e as Atividades Extracurriculares 
media_atividades_extracurriculares =  novo_df_estudantes.pivot_table(values='Media_Notas', index='Atividades_Extracurriculares',
                                                                        columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_atividades_extracurriculares.round(1)
# Out:
# Classificacao_Notas             A    B    C    D    F
# Atividades_Extracurriculares
# Não                           3.6  3.2  2.7  2.2  1.1
# Sim                           3.6  3.2  2.7  2.2  1.2

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e o Esporte
media_esporte = novo_df_estudantes.pivot_table(values='Media_Notas', index='Esportes', 
                                           columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_esporte.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Esportes
# Não                  3.6  3.2  2.7  2.2  1.1
# Sim                  3.7  3.2  2.7  2.2  1.2

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e a Música 
media_musica =  novo_df_estudantes.pivot_table(values='Media_Notas', index='Musica', columns='Classificacao_Notas', 
                                                   aggfunc='mean', fill_value=0)

media_musica.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Musica
# Não                  3.6  3.2  2.7  2.2  1.1
# Sim                  3.7  3.2  2.7  2.2  1.2

# %%
#Aplicando pivot_table para visualizar a relação das médias entre Média das Notas e o Voluntariado
media_voluntariado = novo_df_estudantes.pivot_table(values='Media_Notas', index='Voluntariado', 
                                           columns='Classificacao_Notas', aggfunc='mean', fill_value=0)

media_voluntariado.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Voluntariado
# Não                  3.6  3.2  2.7  2.2  1.2
# Sim                  3.7  3.2  2.7  2.2  1.2

# %% [markdown]
# Análise exploratória das Atividades Extracurriculares:
#
# Na análise das atividades extracurriculares, observou-se que as notas ficaram todas dentro da média geral da classificação em todas as atividades, com a nota F sofrendo queda nas atividades extracurriculares, esporte e música, mas ficando dentro da média geral em voluntariado.
#
# A conclusão da análise é de que as Atividades Extracurriculares não tem impacto significatvo nas notas dos estudantes em geral.

# %% [markdown]
# 6 - 📈 Desempenho Acadêmico

# %%
#Aplicando pivot_table para visualizar as notas máximas da Classificação das Médias
max_classificacao_notas= novo_df_estudantes.pivot_table(values='Media_Notas', columns='Classificacao_Notas', 
                                                       aggfunc='max', fill_value=0)

max_classificacao_notas.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Media_Notas          4.0  3.4  2.9  2.4  1.9

# %%
#Aplicando pivot_table para visualizar as notas mmínimas da Classificação das Médias
min_classificacao_notas = novo_df_estudantes.pivot_table(values='Media_Notas', columns='Classificacao_Notas', 
                                                       aggfunc='min', fill_value=0)

min_classificacao_notas.round(1)
# Out:
# Classificacao_Notas    A    B    C    D    F
# Media_Notas          3.5  3.0  2.5  2.0  0.0

# %% [markdown]
# Análise do Desempenho Acadêmico:
#
# A análise do desempenho acadêmico mostra que o desempenho dos estudantes são variáveis, alcançando tanto notas máximas quanto notas minímas, porém com poucas notas acima da média geral (3.6), mas com muitas notas abaixo da média geral de
# (2.5), sugerindo atenção especial aos estudantes classificados nas notas entre D e F.

# %% [markdown]
# 📈 **Visualização dos Dados**

# %%
#Configuração da ordem da categoria Classificação das Notas, que nos gráficos são mostrados fora da ordem de A à F. 

#Variável para ajustar o parâmetro order= no Boxplot.
ordem_categoria = ['A', 'B', 'C', 'D', 'F']

# %% [markdown]
# Gráficos de Histograma e Boxplot para visualização dos dados.

# %% [markdown]
# 1 - 👥 Detalhes Demográficos

# %%
#Gráficos de Histograma e Boxplot para visualizar a distribuição dos estudantes e a classificação das notas por idade.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição por Idade)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Idade'], kde=True, bins=4, color='goldenrod')
plt.title('Distribuição dos Estudantes por Idade')
plt.xlabel('Idade dos Estudantes')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das Notas por Idade)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Idade', color='darkorange', order=ordem_categoria)
plt.title('Classificação das Notas por Idade')
plt.xlabel('Classificação das Notas')
plt.ylabel('Idade')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação a Idade, os gráficos apresentam um equilíbrio nas idades dos estudantes com leve aumento na idade de 15 anos.
#
# A média da classificação das notas concentra-se na idade entre 15 e 17 anos, com as maiores notas entre 16 e 18 anos e as monores notas concentradas em todas as idades.

# %%
#Gráficos de Histograma e Boxplot para visualizar a distribuição dos estudantes e a classificação das notas por gênero.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição por Gênero)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Genero'], kde=True, color='gold')
plt.title('Distribuição dos Estudantes por Gênero')
plt.xlabel('Gênero dos Estudantes')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das Notas por Gênero)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Genero', color='khaki', order=ordem_categoria)
plt.title('Classificação das Notas por Gênero')
plt.xlabel('Classificação das Notas')
plt.ylabel('Gênero')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação ao Gênero, os gráficos apresentam:
#
# Uma distribuição equilibrada em ambos os gêneros com um leve aumento do gênero feminino.
#
# Uma classificação nas notas também equilibrada em ambos os gêneros.

# %%
#Gráficos de Histograma e Boxplot para visualizar a distribuição dos Alunos e a classificação das notas por Etnia.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição por Etnia)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Etnia'], kde=True, color='peru')
plt.title('Distribuição dos Estudantes por Etnia')
plt.xlabel('Etnia dos Estudantes')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das Notas por Etnia)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Etnia', color='chocolate', order=ordem_categoria)
plt.title('Classificação das Notas por Etnia')
plt.xlabel('Classificação das Notas')
plt.ylabel('Etnia')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação a Etnia, os gráficos apresentam:
#
# Uma variação entre as etnias, com o grupo caucasiano predominantemente maior, os grupos asiáticos e afrodescendentes equilibrados e o grupo Outra bem abaixo.
#
# Na classificação das notas, as maiores notas estão dividas entre os grupos caucasiano, asiático e afrodescendente, as médias ficaram também entre os 3 grupos, porém na nota B os afrodescendentes obteram médias maiores que os grupos caucasianos e asiáticos, as menores notas se equilibram em todos os grupos, com o grupo outra equilibrada em todas as notas.

# %% [markdown]
# -

# %% [markdown]
# Resumo dos Detalhes Demográficos:
#
# No Detalhe demográfico, os gráficos mostram que o desempenho dos estudantes são afetados de acordo com a idade, onde os mais velhos alcançam maiores notas, já o gênero não influencia no desempenho em geral e os grupos etnicos possui um forte impacto no desempenho dos estudantes.
#
# Resumindo, a idade e a etnia tem forte influência na classificaçao das notas.

# %% [markdown]
# 2 - 👨‍👩‍👧 Educação dos Pais e Envolvimento Parental

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas da Escolaridade dos Pais.

#Configuração da figura
plt.figure(figsize=(18, 9))

#Gráfico de histograma (Distribuição da Escolaridade dos Pais)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Escolaridade_Pais'], kde=True, color='lightblue')
plt.title('Distribuição pela Escolaridade dos Pais')
plt.xlabel('Escolaridade dos Pais')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das Notas Escolaridade dos Pais)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Escolaridade_Pais', color='darkseagreen', order=ordem_categoria)
plt.title('Classificação das Notas por Escolaridade dos Pais')
plt.xlabel('Classificação das Notas')
plt.ylabel('Escolaridade dos Pais')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação a Escolaridade dos pais, os gráficos apresentam:
#
# Uma distribuição variada e desproporcional entre os grupos, porém os números são maiores entre os pais com alguma faculdade e ensino médio e menores entre os graduados e pós-graduados ou superior, e o número dos pais em NENHUM sofrem pequena variação acima do grupo pós-graduado ou superior.
#
# Na classificação das notas é apresentado um domínio do ensino médio em todas as notas, com as médias variando entre alguma faculdade e graduação, já o grupo pós-graduação ou superior só é destacado na nota A, e o grupo NENHUM fica abaixo sem sofrer variação, apresentando um outlier na nota A.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas do Apoio dos Pais.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição do Apoio dos Pais)
plt.subplot(1, 2, 1)
sns.histplot(data=novo_df_estudantes, x="Apoio_Pais", hue="Classificacao_Notas", kde=True, color='mediumseagreen')
plt.title('Distribuição por Apoio dos Pais')
plt.xlabel('Apoio dos Pais')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Apoio dos Pais)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Apoio_Pais', color='cadetblue', order=ordem_categoria)
plt.title('Classificação das Notas por Apoio dos Pais')
plt.xlabel('Classificação das Notas')
plt.ylabel('Apoio dos Pais')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação ao Apoio dos Pais, os gráficos apresentam:
#
# Uma distribuição variada, porém homogênea entre alguns grupos. O apoio dos pais é maior entre os grupos moderado e alto e menores entre muito alto e nenhum, com o grupo baixo se mantendo entre os outros 4 grupos.
#
# Na classificação das notas, o gráfico demonstra que as maiores notas estão concetradas no grupo alto, enquantos as médias variam entre moderado e baixo. Na nota A é mostrado um sútil aumento para o grupo muito alto. Já o grupo nenhum ficou abaixo em todas as notas sem sofrer variação.

# %% [markdown]
# -

# %% [markdown]
# Resumo da Educação dos Pais e Envolvimento Parental:
#
# Os gráficos mostram que há um forte impacto no desempenho dos estudantes em relação ao envolvimento dos pais, apresentando melhores resultados dos alunos que possuem pais com um nível de escolaridade maior e que apoiam os alunos.
#
# Resumindo, a educação e o envolvimento dos pais impactam de forma positiva no desempenho dos estudantes.

# %% [markdown]
# 3 - 📚 Hábitos de Estudo

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas das Horas de Estudos Semanais.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Horas de Estudo Semanais)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Horas_Estudo_Semanais'], bins=20, kde=True, color='deepskyblue')
plt.title('Distribuição das Horas de Estudo Semanais')
plt.xlabel('Horas de Estudo Semanais')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das notas das Horas de Estudos Semanais)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Horas_Estudo_Semanais', color='powderblue', order=ordem_categoria)
plt.title('Classificação das Notas por Horas de Estudos Semanais')
plt.xlabel('Classificação das Notas')
plt.ylabel('Horas de Estudos Semanais')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação as horas de estudos semanais, os gráficos apresentam:
#
# Que a maioria dos estudantes estudam uma média de 8 à 10 horas por semana, com a média variando entre 5 e 12 horas semanais.
#
# A classificação das notas estão distribuídas com as notas maiores entre os alunos que estudam de 7 à 17 horas semanais, as monores entre os que estudam de 4 à 13 horas semanais, e as médias ficam entre 5 e 13 horas semanais.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas das Faltas.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Faltas)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Faltas'], bins=30, kde=True, color='sandybrown')
plt.title('Distribuição das Faltas')
plt.xlabel('Número de Faltas')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das notas das Faltas)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Faltas', color='orangered', order=ordem_categoria)
plt.title('Classificação das Notas por Faltas')
plt.xlabel('Classificação das Notas')
plt.ylabel('Número de Faltas')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação as Faltas, os gráficos apresentam:
#
# Que a maioria dos estudantes possuem entre 0 e 5 faltas e a minoria possui entre 9 e 15 faltas com variação entre os que faltam entre 20 e 25 vezes.
#
# A classificação das notas estão distribuídas com as maiores entre 0 e 3 faltas com um outlier, com as médias entre 3 e 14 faltas com diversos outliers e as menores notas distribuidas entre 17 e 25 faltas com outliers.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas das Aulas Particulares.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Aulas Particulares)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Aulas_Particulares'], kde=True, color='greenyellow')
plt.title('Distribuição das Aulas Particulares')
plt.xlabel('Aulas Particulares')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Aulas Particulares)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Aulas_Particulares', color='darkkhaki', order=ordem_categoria)
plt.title('Classificação das Notas por Aulas Particulares')
plt.xlabel('Classificação das Notas')
plt.ylabel('Aulas Particulares')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação as Aulas Particulares, os gráficos apresentam:
#
# Que a maioria dos estudantes não participam de aulas particulares.
#
# A classificação das notas são equilibradas entre os estudantes que participam ou não de aulas particulares.

# %% [markdown]
# -

# %% [markdown]
# Resumo dos Hábitos de Estudo:
#
# Os gráficos mostram que os alunos que passam mais horas estudando, possuem um desempenho melhor nas notas em relação a classificação das notas. Já nas faltas, apesar de que é apresentado uma frequência maior dos estudantes, o desempenho das notas caem drasticamente à medida em que o número de faltas aumenta. A participação das aulas particulares não sofre impacto nas notas, mesmo tendo pouca participação de estudantes em aulas particulares.
#
# Resumindo, as faltas tem um grande impacto no desempenho das notas, mesmo com uma maior frequência dos alunos, as horas de estudos semanais parecem estar na média contribuindo para um bom desempenho das notas e as aulas particulares não influenciam no desempenho dos estudantes.

# %% [markdown]
# 4 - 🏫 Atividades Extracurriculares

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas das Atividades Extracurriculares.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Atividades Extracurriculares)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Atividades_Extracurriculares'], bins=20, kde=True, color='skyblue')
plt.title('Distribuição das Atividades Extracurriculares')
plt.xlabel('Atividades Extracurriculares')
plt.ylabel('Número de Estudantes')

#Gráfico de boxplot (Classificação das notas Atividades Extracurriculares)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Atividades_Extracurriculares', color='dodgerblue', order=ordem_categoria)
plt.title('Classificação das Notas por Atividades Extracurriculares')
plt.xlabel('Classificação das Notas')
plt.ylabel('Atividades Extracurriculares')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação as Atividades Extracurriculares, os gráficos apresentam:
#
# Que a maioria dos estudantes não tem aulas extracurriculares.
#
# A classificação das notas se mantém equilibrada, mesmo com menos alunos praticando as atividades extracurriculares.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas dos Esportes.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição do Esporte)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Esportes'], kde=True, color='steelblue')
plt.title('Distribuição das Atividades por Esportes')
plt.xlabel('Esportes')
plt.ylabel('Número de Estudantes')

#Gráfico de boxplot (Classificação das notas do Eporte)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Esportes', color='skyblue', order=ordem_categoria)
plt.title('Classificação das Notas por Esportes')
plt.xlabel('Classificação das Notas')
plt.ylabel('Esportes')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação aos Esportes, os gráficos apresentam:
#
# Que a maioria dos estudantes não praticam aulas relacionda ao esporte.
#
# A classificação das notas se mantém equilibrada, embora o número de estudantes seja menor para quem pratica.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas da Música.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Atividades por Música)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Musica'], bins=20, kde=True, color='palegreen')
plt.title('Distribuição das Atividades por Música')
plt.xlabel('Música')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das notas da Música)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Musica', color='lightgreen', order=ordem_categoria)
plt.title('Classificação das Notas por Música')
plt.xlabel('Classificação das Notas')
plt.ylabel('Música')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação a Música, os gráficos apresentam:
#
# Que a maioria dos estudantes não fazem aulas de música.
#
# A classificação das notas sofre variações devido a um número bem menor de quem pratica esta atividade, porém a Nota A se mantém equilbrada para quem pratica e não pratica e sofre uma leve variação na nota B com as notas maiores para quem não pratica. Já o restante das notas ficam bem abaixo para os que não praticam, variando em todas as notas, porém com ocorrêcia de outliers para quem pratica música.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação das notas do Voluntariado.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Atividades por Voluntariado)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Voluntariado'], kde=True, color='firebrick')
plt.title('Distribuição das Atividades por Voluntariado')
plt.xlabel('Voluntariado')
plt.ylabel('Número de Estudantes')

#Gráfico de Boxplot (Classificação das notas do Voluntariado)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Voluntariado', color='brown', order=ordem_categoria)
plt.title('Classificação das Notas por Voluntariado')
plt.xlabel('Classificação das Notas')
plt.ylabel('Voluntariado')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação ao Voluntariado, os gráficos apresentam:
#
# Que a maioria dos estudantes não participam de voluntariado.
#
# A classificação das notas não sofre variações para quem não participa de voluntariado, e para os que participa só ocorre 1 outlier para cada nota.

# %% [markdown]
# -

# %% [markdown]
# Resumo das Atividades Extracurriculares:
#
# Os gráficos mostram que em todas as atividades há uma número muito pequeno de estudantes que praticam tais atividades, principalmente na música e voluntariado com números expressivamente menores de não participantes. Embora a grande maioria não participe das atividades, as notas principalmente em atividades extracurriculares e esporte não sofrem variações se mantendo equilibradas para ambas atividades, já a música e o voluntariado, provavelmente por um número ainda menor de não participantes, as notas sofreram uma maior variação com as notas mais concentradas nos não participantes.
#
# Resumindo, as Atividades Extracurriculares não influenciam nas notas em si, mas poderiam melhorar o desempenho das notas de modo geral.

# %% [markdown]
# 5 - 📈 Desempenho Acadêmico

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e a classificação da média das notas.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição das Notas)
plt.subplot(1, 2, 1)
sns.histplot(novo_df_estudantes['Media_Notas'], bins=30, color='mediumblue', kde=True, edgecolor='black')
plt.title('Distribuição da Médias das Notas')
plt.xlabel('Faixa das Notas')
plt.ylabel('Número de Estudantes')

#Gráfico de boxplot (Classificação das notas por número de estudantes)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='ID_Aluno', color='mediumpurple', order=ordem_categoria)
plt.title('Classificação das Notas por Número de Estudantes')
plt.xlabel('Classificação das Notas')
plt.ylabel('Número de Estudantes')

plt.tight_layout()
plt.show()

# %% [markdown]
# Em relação ao desemepenho das médias das notas, os gráficos apresentam:
#
# Que a média da maioria dos estudantes está entre 1.0 e 3.0, com um pouco mais da metade entre 0.0 e 1.0, e menos da metade com as médias entre 3.0 e 4.0.
#
# A classficação das notas sofreu leve variação nas médias em todas as notas entre 500 e 1.900 estudantes, sendo as notas A com menor variação.

# %%
#Gráfico de Histograma e Boxplot para visualizar a distribuição e classificação da classificação das notas.

#Configuração da figura
plt.figure(figsize=(12, 6))

#Gráfico de histograma (Distribuição da Classificação das Notas)
plt.subplot(1, 2, 1)

#Configuração da ordem da categoria da classificação das notas para o histograma
novo_df_estudantes['Classificacao_Notas'] = pd.Categorical(novo_df_estudantes['Classificacao_Notas'], categories=ordem_categoria, ordered=True)

sns.histplot(novo_df_estudantes['Classificacao_Notas'], bins=5, color='cadetblue', kde=True, edgecolor='black')
plt.title('Distribuição da Classificação das Notas')
plt.xlabel('Faixa de Classificação')
plt.ylabel('Número de Estudantes')

#Gráfico de boxplot (Classificação das Notas por Média das Notas)
plt.subplot(1, 2, 2)
sns.boxplot(data=novo_df_estudantes, x='Classificacao_Notas', y='Media_Notas', color='darkcyan', order=ordem_categoria)
plt.title('Classificação das Notas por Média das Notas')
plt.xlabel('Classificação das Notas')
plt.ylabel('Média das Notas')

plt.tight_layout()
plt.show()

# %%
sns.heatmap(novo_df_estudantes.corr(numeric_only=True), annot=True, cmap='coolwarm')

plt.title('Correlção entre as Notas dos Estudantes')
plt.show()

# %%
novo_df_estudantes.corr(numeric_only=True).abs()[['Media_Notas']]
# Out:
#                        Media_Notas
# ID_Aluno                  0.001591
# Idade                     0.000483
# Horas_Estudo_Semanais     0.177438
# Faltas                    0.918728
# Media_Notas               1.000000

# %% [markdown]
# Em relação ao desempenho da classificação das notas, os gráficos apresentam:
#
# Que a variação da classificação foi muito grande em relação a nota A para F, mostrando que um pequeno número de estudantes alcançaram notas elevadas, com um leve aumento nas notas médias e um número elevadissímo de estudantes classificados com as notas mais baixas.
#
# Na classificação geral das notas, as classificaçãoes se mostraram constantes com uma margem pequena de notas maiores na categoria A, sofrendo um leve aumento até a nota F que possui uma margem muito maior de notas.

# %% [markdown]
# -

# %% [markdown]
# Resumo do Desempenho Acadêmico:
#
# Os gráficos demonstram que o desempenho dos estudantes foi significamente ruim, com estudantes classificados na maior parte na nota F e as notas B, C e D ainda muito abaixo da F, com a nota A muito abaixo de todas as outras.

# %% [markdown]
# ### **Resposta da Pergunta Norteadora**:
# **"Quais fatores demográficos, acadêmicos e comportamentais mais influenciam a classificação e a média de notas dos estudantes?"**
#
# **Resposta:**
#
# Os fatores demográficos que mais influenciam a classificação e a média dos estudantes são a Idade e a Etnia, a idade demonstra um melhor desempenho dos estudantes a medida em que estes envelhecem. Já a etnia tem uma certa influência através da diversidade dos grupos etnicos, que provavalmente são influenciados pelos níveis culturais e sócio-econômicos.
#
# Os fatores acadêmicos não tiveram uma forte influência na classificação e na média dos estudantes, uma vez que a grande maioria dos estudantes não participaram de atividades extracurriculares, provavelmente por falta de interesse dos estudantes nestas atividades, isso com certeza impactou muito o desempenho da classificação e da média.
#
# Os fatores comportamentais tiveram uma influência muito siginificativa na classificacação e na média dos estudantes, sem dúvida as faltas, que segundo os dados, apesar dos alunos terem uma boa frequência nas aulas, as notas dos que faltam, por serem as mais baixas a nível de notas, impactaram muito o desempenho da classificação e da média de modo geral. Outro fator que também pode ter certa influência é o baixo número de participantes nas aulas particulares, que apesar das notas desse grupo não terem influenciado diretamente nas notas, mas impactaram a classificação e a média de modo geral. Já o que pode ter contribuído para melhores notas foram o apoio dos pais e as horas de estudos semanais.
